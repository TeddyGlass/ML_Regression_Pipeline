# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1301)
# y_train.shape (1379,)
# len(len(columns) 1301
# c:\users\mmi-05\miniconda3\envs\ml\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# LightGBM R2:  0.30075337431629623
# LightGBM RMSE:  0.5766616905010241

# %% [markdown]
# # FSしてみた

# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# len(len(columns) 1013
# c:\users\mmi-05\miniconda3\envs\ml\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# LightGBM R2:  0.2837318992500063
# LightGBM RMSE:  0.5836382091670115

# %% [markdown]
# #### 5fold

# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# len(len(columns) 1013
# c:\users\mmi-05\miniconda3\envs\ml\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# LightGBM R2:  0.2974677726091438
# LightGBM RMSE:  0.5780149041669757

# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# len(len(columns) 1013
# c:\users\mmi-05\miniconda3\envs\ml\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# LightGBM R2:  0.30594399390475946
# LightGBM RMSE:  0.5745173776943661

# %% [markdown]
# 目的変数をビン化して層化抽出

# %% [markdown]
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# len(len(columns) 1013
# LightGBM R2:  0.3414517008795196
# LightGBM RMSE:  0.5596283760324362

# %% [markdown]
# lambda=1<br>
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# len(len(columns) 1013
# LightGBM R2:  0.34006073887257005
# LightGBM RMSE:  0.5602190777357127

# %% [markdown]
# lambda=10<br>
# X_train.shape (1379, 1013)<br>
# y_train.shape (1379,)<br>
# len(len(columns) 1013<br>
# LightGBM R2:  0.33794727036729244<br>
# LightGBM RMSE:  0.5611154169984858<br>
# 設定しないほうがいいかも

# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# len(len(columns) 1013
# LightGBM R2:  0.3414517008795196
# LightGBM RMSE:  0.5596283760324362
# RMSE [0.5469957129568985, 0.5126016917532965, 0.5414046501113545, 0.6236636147567316, 0.5883792347849605, 0.5153389044782263, 0.5789813061395768, 0.5649385145063353, 0.5964875999873261, 0.5152834473310914] R2 [0.3720468117044662, 0.24128836000276888, 0.32001384229203056, 0.284536422892289, 0.40019316610684363, 0.2808502888636768, 0.39091285574723367, 0.41601827255684676, 0.15160713092238665, 0.4591534988161241]

# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# len(len(columns) 1013
# [15:59:36] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:00:55] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:02:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:03:45] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:05:18] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %% [markdown]
# ### lgbの目的変数をcutでビン分割してみる

# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# len(len(columns) 1013
# [17:33:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# c:\users\mmi-05\miniconda3\envs\ml\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# [17:34:34] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:36:21] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:37:28] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %% [markdown]
# #### ビンをcutで目的変数の値に準じて10分割した方がCVの評価が安定していた

# %%
# %pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.1.0-cp36-cp36m-win_amd64.whl (355.9 MB)
# ...
#   Using cached tensorflow_estimator-2.1.0-py2.py3-none-any.whl (448 kB)
# ...
# Processing c:\users\mmi-05\appdata\local\pip\cache\wheels\5c\2e\7e\a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd\gast-0.2.2-cp36-none-any.whl
# Processing c:\users\mmi-05\appdata\local\pip\cache\wheels\2c\b1\94\43d03e130b929aae7ba3f8d15cbd7bc0d1cb5bb38a5c721833\opt_einsum-3.1.0-cp36-none-any.whl
# ...
# Processing c:\users\mmi-05\appdata\local\pip\cache\wheels\8e\28\49\fad4e7f0b9a1227708cbbee4487ac8558a7334849cb81c813d\absl_py-0.9.0-cp36-none-any.whl
# ...
#   Using cached protobuf-3.11.3-cp36-cp36m-win_amd64.whl (1.1 MB)
# ...
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# ...
#   Using cached scipy-1.4.1-cp36-cp36m-win_amd64.whl (30.8 MB)
# Processing c:\users\mmi-05\appdata\local\pip\cache\wheels\7c\06\54\bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6\termcolor-1.1.0-cp36-none-any.whl
# ...

# %%
# %run -i run.py
# Out:
# C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# X_test.shape (94, 1013)
# y_test.shape (94,)
# len(len(columns) 1013
# LightGBM R2 Val:  0.32635074251367235
# LightGBM RMSE Val:  0.5660083378971043
# LightGBM R2 Test:  0.3063589977754422
# LightGBM RMSE Test:  0.5327389258014226
# each_RMSE
# 0.5826494474765201
# 0.5873752460144767
# 0.5198537513551031
# 0.5915442817312889
# 0.521974172345379
# 0.5472751492406319
# 0.5708599865465211
# 0.5916699528898981
# 0.5725299626005754
# 0.5683266482374293
# each_R2
# 0.3998350059032344
# 0.34669356184861166
# 0.3621467217726262
# 0.2509601195769193
# 0.3908152678830874
# 0.320428287981705
# 0.311221343744583
# 0.3215799971959773
# 0.2094500879249096
# ...

# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# X_test.shape (94, 1013)
# y_test.shape (94,)
# len(len(columns) 1013
# C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# LightGBM R2 Val:  0.3057754173401095
# LightGBM RMSE Val:  0.5745871446042674
# LightGBM R2 Test:  0.30287131343579377
# LightGBM RMSE Test:  0.5340765741526027
# each_RMSE
# 0.5861858009144074
# 0.596048083091173
# 0.5238701896686289
# 0.6011586703230882
# 0.5395219392370468
# 0.5804017345596557
# 0.564698314960549
# 0.6047659909618045
# 0.5712549909610849
# 0.5723203477947769
# each_R2
# 0.39252757114577785
# 0.32725845320907654
# 0.35225241949808705
# 0.22641391296287916
# 0.3491675464797285
# 0.23566941262259
# 0.32600999128234587
# 0.2912152971400994
# ...

# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# X_test.shape (94, 1013)
# y_test.shape (94,)
# len(len(columns) 1013
# C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# LightGBM R2 Val:  0.32089875848974136
# LightGBM RMSE Val:  0.5682941341594856
# LightGBM R2 Test:  0.31471579050071286
# LightGBM RMSE Test:  0.5295200566516041
# each_RMSE
# 0.582997742273456
# 0.5829974631643452
# 0.5326797956248079
# 0.6025210940047617
# 0.5235719819782315
# 0.5579128015542217
# 0.5686202876604595
# 0.6017362217652493
# 0.5609349488116261
# 0.5630973506161536
# each_R2
# 0.3991172610441992
# 0.3563956241726678
# 0.33028368910807937
# 0.2229035375555617
# 0.38708002174366873
# 0.293753205601068
# 0.316615417995485
# 0.2982992764372102
# ...

# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# X_test.shape (94, 1013)
# y_test.shape (94,)
# len(len(columns) 1013
# C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# CatBoost R2 Val:  0.1887267836000508
# CatBoost RMSE Val:  0.6211399750598786
# CatBoost R2 Test:  0.12824721782258186
# CatBoost RMSE Test:  0.5972328990742736
# each_RMSE
# 0.6581174291964249
# 0.6453845354099144
# 0.570431319863975
# 0.6342955109205409
# 0.5945261949909089
# 0.6102670330157338
# 0.6067597997306083
# 0.6620450565533451
# 0.6210098810291419
# 0.6006431194977591
# each_R2
# 0.2342927346520438
# 0.21128015617361595
# 0.23199304538181575
# 0.13878081555833255
# 0.2096982010466999
# 0.15498648333668874
# 0.2218665703943351
# 0.15059520395419979
# ...
