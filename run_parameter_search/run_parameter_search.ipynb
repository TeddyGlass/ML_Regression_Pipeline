# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# len(len(columns) 1013
# [I 2020-02-18 17:36:17,631] Finished trial#0 resulted in value: 0.5772103723436364. Current best value is 0.5772103723436364 with parameters: {'num_leaves': 62, 'subsample': 0.7363706130405656, 'colsample_bytree': 0.8813365546268426, 'min_child_weight': 0.46117814635847987, 'min_child_samples': 58, 'min_split_gain': 0.001044796375287434}.
# [I 2020-02-18 17:36:18,404] Finished trial#1 resulted in value: 0.5763517602619055. Current best value is 0.5763517602619055 with parameters: {'num_leaves': 57, 'subsample': 0.6550087783104126, 'colsample_bytree': 0.7506557031468073, 'min_child_weight': 0.4242072849836787, 'min_child_samples': 45, 'min_split_gain': 0.0009211712509502564}.
# ...

# %% [markdown]
# early stopping round 15 : RMSE 0.5797307953733697 seed1234<br>
# early stopping round 15 : RMSE 0.5797307953733697 seed4321<br>
# early stopping round 10 : RMSE 0.583032876491307 seed4321<br>

# %% [markdown]
# ### moedred

# %% [markdown]
# そのまま突っ込んだやつ　depth5, early_stopping_round15: 0.5882897250871137<br>
# そのまま突っ込んだやつ　depth7, early_stopping_round15: 0.5825893658131093<br>
# LightGBM_RMSE:  0.5854260854326152
# LightGBM_params:  {'learning_rate': 0.05, 'n_estimators': 10000, 'max_depth': 7, 'num_leaves': 111, 'subsample': 0.8667330147710665, 'colsample_bytree': 0.7468876741559535, 'min_child_weight': 0.02300322119879625, 'min_split_gain': 0.019665909958519738, 'random_state': 1112, 'n_jobs': -1, 'min_child_samples': 35}<br>

# %% [markdown]
# LightGBM_RMSE:  0.5798282030546605
# LightGBM_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': 9, 'num_leaves': 433, 'subsample': 0.7198507789957935, 'colsample_bytree': 0.7810581988384452, 'min_child_weight': 0.31848280352350933, 'min_split_gain': 3.01316144328497e-06, 'random_state': 1112, 'n_jobs': -1, 'min_child_samples': 13}

# %% [markdown]
# LightGBM_RMSE:  0.5798254403521766
# LightGBM_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': 9, 'num_leaves': 396, 'subsample': 0.6583945865128847, 'colsample_bytree': 0.7021719548710103, 'min_child_weight': 0.0020331268869397687, 'min_split_gain': 4.212330570736677e-07, 'random_state': 1112, 'n_jobs': -1, 'min_child_samples': 19}

# %% [markdown]
# LightGBM_RMSE:  0.5798254403521766
# LightGBM_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': 9, 'num_leaves': 396, 'subsample': 0.5583945865128848, 'colsample_bytree': 0.7021719548710103, 'min_child_weight': 0.0020331268869397687, 'min_split_gain': 4.2123305707366724e-08, 'random_state': 1112, 'n_jobs': -1, 'min_child_samples': 19}

# %% [markdown]
# depthは-1でサーチ<br>
# LightGBM_RMSE:  0.5829034167988569
# LightGBM_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': -1, 'num_leaves': 20, 'subsample': 0.6207361229804399, 'colsample_bytree': 0.8424246074261784, 'min_child_weight': 0.00019565830360256686, 'min_split_gain': 2.2502384918634014e-08, 'random_state': 1112, 'n_jobs': -1, 'min_child_samples': 22}

# %% [markdown]
# LightGBM_RMSE:  0.5835694149387438
# LightGBM_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': -1, 'num_leaves': 668, 'subsample': 0.6142511017475885, 'colsample_bytree': 0.8157150401248677, 'min_child_weight': 25.619294880868612, 'min_split_gain': 0.0007066622603781092, 'random_state': 1112, 'n_jobs': -1, 'min_child_samples': 4}

# %% [markdown]
# LightGBM_RMSE:  0.5856209114992386
# LightGBM_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': -1, 'num_leaves': 472, 'subsample': 0.5594695043337481, 'colsample_bytree': 0.6658608359180042, 'min_child_weight': 13.106478204816979, 'min_split_gain': 5.8211139092682104e-05, 'random_state': 1112, 'n_jobs': -1, 'min_child_samples': 16}

# %% [markdown]
# LightGBM_RMSE:  0.5837472414590825
# LightGBM_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': -1, 'num_leaves': 29, 'subsample': 0.5808273238743553, 'colsample_bytree': 0.7779264673026249, 'min_child_weight': 11.662150815963107, 'min_split_gain': 7.59576243507072e-05, 'random_state': 1112, 'n_jobs': -1, 'min_child_samples': 22}

# %% [markdown]
# LightGBM_RMSE:  0.5818071203453534
# LightGBM_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': -1, 'num_leaves': 30, 'subsample': 0.606764721046304, 'colsample_bytree': 0.6712236570687783, 'min_child_weight': 15.216933075961114, 'min_split_gain': 0.0008737362299638684, 'random_state': 1112, 'n_jobs': -1, 'min_child_samples': 24}

# %% [markdown]
# # FSしてみた

# %% [markdown]
# LightGBM_RMSE:  0.5666317537379004
# LightGBM_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': -1, 'num_leaves': 47, 'subsample': 0.7988491018479462, 'colsample_bytree': 0.949798784341791, 'min_child_weight': 0.9172294838966212, 'min_split_gain': 0.0012376893862917184, 'random_state': 1112, 'n_jobs': -1, 'min_child_samples': 38}

# %% [markdown]
# 5fold<br>
# LightGBM_RMSE:  0.5798162193460897
# LightGBM_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': -1, 'num_leaves': 48, 'subsample': 0.6977092208136354, 'colsample_bytree': 0.6530242288282535, 'min_child_weight': 5.393608626303465, 'min_split_gain': 8.815308339324205e-05, 'random_state': 1112, 'n_jobs': -1, 'min_child_samples': 25}

# %% [markdown]
# 目的変数をビン化して層化抽出kfold<br>
# LightGBM_RMSE:  0.5627701361976495
# LightGBM_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': -1, 'num_leaves': 53, 'subsample': 0.754231159469259, 'colsample_bytree': 0.6618117514343589, 'min_child_weight': 2.536982098343908, 'min_split_gain': 0.0019766625905465194, 'random_state': 1112, 'n_jobs': -1, 'min_child_samples': 29}

# %% [markdown]
# # XGboost

# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# len(len(columns) 1013
# c:\users\mmi-05\miniconda3\envs\ml\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning:
#
# Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#
# c:\users\mmi-05\miniconda3\envs\ml\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning:
#
# Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#
# c:\users\mmi-05\miniconda3\envs\ml\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning:
#
# Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#
# ...

# %% [markdown]
# XGBoost_RMSE:  0.5767673496977253
# XGBoost_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': 7, 'subsample': 0.9098927473650098, 'colsample_bytree': 0.725136609618952, 'gamma': 7.31600702967298e-05, 'min_child_weight': 9.356632482180261, 'random_state': 1112, 'n_jobs': -1}

# %% [markdown]
# XGBoost_RMSE:  0.5776355153540595
# XGBoost_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': 5, 'subsample': 0.7942795704453083, 'colsample_bytree': 0.7676352554582452, 'gamma': 5.56447414983396e-06, 'min_child_weight': 2.871437810392839, 'random_state': 1112, 'n_jobs': -1}

# %% [markdown]
# XGBoost_RMSE:  0.5749446137342074
# XGBoost_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': 9, 'subsample': 0.9098927473650098, 'colsample_bytree': 0.725136609618952, 'gamma': 7.31600702967298e-05, 'min_child_weight': 9.356632482180261, 'random_state': 1112, 'n_jobs': -1}

# %% [markdown]
# XGBoost_RMSE:  0.5763457986264392
# XGBoost_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': 11, 'subsample': 0.7405840508788157, 'colsample_bytree': 0.9441746595782863, 'gamma': 0.00020703252573923847, 'min_child_weight': 8.763740759492753, 'random_state': 1112, 'n_jobs': -1}

# %% [markdown]
# XGBoost_RMSE:  0.569574388471391
# XGBoost_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': 9, 'subsample': 0.8626092186328238, 'colsample_bytree': 0.7758865021707626, 'gamma': 2.1257053895326382e-07, 'min_child_weight': 14.980248904503854, 'random_state': 1112, 'n_jobs': -1}<br>
# ↑min_child_weightが効いていた模様

# %% [markdown]
# XGBoost_RMSE:  0.5760483954168049
# XGBoost_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': 9, 'subsample': 0.8626092186328238, 'colsample_bytree': 0.9017730043415251, 'gamma': 2.1257053895326382e-07, 'min_child_weight': 14.980248904503854, 'random_state': 1112, 'n_jobs': -1}<br>
# ↑colsample_bytreeを無理やり低くした方が性能が上がる

# %% [markdown]
# ### colsample_bylevelも付け加えてモデルに多様性を与えてみる

# %% [markdown]
# XGBoost_RMSE:  0.5749959295896361
# XGBoost_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': 9, 'subsample': 0.8039384462597006, 'colsample_bytree': 0.7499936825246107, 'colsample_bylevel': 0.6817725455170441, 'gamma': 1.114704117454071e-07, 'min_child_weight': 3.0523132563257214, 'random_state': 1112, 'n_jobs': -1}<br>
# 逆に下がった

# %% [markdown]
# XGBoost_RMSE:  0.5774588358397581
# XGBoost_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': 9, 'subsample': 0.6779980131109462, 'colsample_bylevel': 0.7390582326442039, 'gamma': 0.26343527074807915, 'min_child_weight': 7.185151901944295, 'random_state': 1112, 'n_jobs': -1}

# %% [markdown]
# XGBoost_RMSE:  0.569574388471391
# XGBoost_params:  {'learning_rate': 0.1, 'n_estimators': 10000, 'max_depth': 9, 'subsample': 0.8626092186328238, 'colsample_bytree': 0.7758865021707626, 'gamma': 2.1257053895326382e-07, 'min_child_weight': 14.980248904503854, 'random_state': 1112, 'n_jobs': -1}

# %% [markdown]
# ### ビン化をcutに変更してみる

# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# len(len(columns) 1013
# c:\users\mmi-05\miniconda3\envs\ml\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning:
#
# Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#
# c:\users\mmi-05\miniconda3\envs\ml\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning:
#
# Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#
# c:\users\mmi-05\miniconda3\envs\ml\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning:
#
# Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#
# ...

# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import EarlyStopping
from keras.layers.advanced_activations import PReLU
from keras.layers.core import Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.optimizers import SGD, Adam
from sklearn.preprocessing import StandardScaler
import optuna
# Out:
# Using TensorFlow backend.
# C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
from sklearn.datasets import load_boston
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBRegressor
from sklearn.model_selection import StratifiedKFold

# %%
bos = load_boston()
X_train = bos['data']
y_train = bos['target']

# %%
# obj_bin
labels = np.arange(10)
y_train_bins = pd.cut(y_train, 10, labels=labels)

# %%
model = XGBRegressor()
kf = StratifiedKFold(n_splits=2, random_state=0, shuffle=True)
model_list = []

for tr_idx, va_idx in kf.split(X_train, y_train_bins):
    # training
    eval_set = [(X_train[tr_idx], y_train[tr_idx]), (X_train[va_idx], y_train[va_idx])]
    model.fit(
        X_train[tr_idx],
        y_train[tr_idx],
        early_stopping_rounds=500,
        eval_set=eval_set,
        eval_metric='rmse',
        verbose=0
    )
    model_list.append(model)
# Out:
# [13:57:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:57:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
model_list[0].evals_result_
# Out:
# {'validation_0': {'rmse': [21.772715,
#    19.750973,
#    17.931368,
#    16.289526,
#    14.801123,
#    13.468414,
#    12.275335,
#    11.187762,
#    10.216969,
#    9.350826,
#    8.558468,
#    7.851568,
#    7.222807,
#    6.644018,
#    6.128327,
#    5.671732,
#    5.263908,
#    4.895821,
#    4.575748,
#    4.285537,
#    4.033026,
#    3.803305,
#    3.594835,
#    3.419581,
#    3.256455,
#    3.103538,
#    2.97608,
#    2.852688,
#    2.749024,
#    2.658538,
#    2.575062,
#    2.505416,
#    2.439479,
#    2.372769,
#    2.323252,
#    2.275129,
#    2.234745,
#    2.186769,
#    2.152768,
#    2.112466,
#    2.082968,
#    2.057798,
#    2.02833,
#    2.00879,
#    1.979515,
#    1.957216,
#    1.939274,
#    1.912144,
#    1.896605,
#    1.875358,
#    1.859809,
#    1.844004,
#    1.83185,
#    1.817499,
#    1.796713,
#    1.78311,
#    1.765448,
#    1.748874,
#    1.731715,
#    1.710181,
#    1.699279,
#    1.686911,
#    1.669547,
#    1.653848,
# ...

# %%
train_rmse = np.array(model_list[0].evals_result_['validation_0']['rmse'])
valid_rmse = np.array(model_list[0].evals_result_['validation_1']['rmse'])
palette = sns.diverging_palette(220, 20, n=2)
width = np.arange(train_rmse.shape[0])
plt.figure(figsize=(10,7.32))
plt.title('Learning_Curve', fontsize=15)
plt.xlabel('Estimators', fontsize=15)
plt.ylabel('RMSE', fontsize=15)
plt.plot(width, train_rmse, label='train_ramse', color=palette[0])
plt.plot(width, valid_rmse, label='valid_rmse', color=palette[1])
plt.legend(loc='upper right', fontsize=13)
plt.show()

# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import EarlyStopping
from keras.layers.advanced_activations import PReLU
from keras.layers.core import Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.optimizers import SGD, Adam
from sklearn.preprocessing import StandardScaler
import optuna
from load_data import load_csv
from config import params


# params
params = params()
params_mlp = params['Regressor']['mlp']

# data sets
X_train, y_train, columns = load_csv()
print('X_train.shape', X_train.shape)
print('y_train.shape', y_train.shape)
print('len(len(columns)', len(columns))

# obj_bin
labels = np.arange(10)
y_train_bins = pd.cut(y_train, 10, labels=labels)


#######################################################S
# class
class MLP:


    def __init__(self):
        self.input_dropout = 0.1
        self.hidden_dropout = 0.1
        self.units = 32
        self.n_layers = 2
        self.batch_norm = 'act'
        self.batch_size = 32
        self.model=None
        self.scaler = StandardScaler()


    def create_graph (self, input_dropout, hidden_dropout, n_layers, batch_norm, units):
        self.model = Sequential()
        # input layer
        self.model.add(Dropout(self.input_dropout, input_shape=(X_train.shape[1],)))
        # hidden layer
        for i in range(self.n_layers):
            self.model.add(Dense(self.units))
            if self.batch_norm == 'act':
                self.model.add(BatchNormalization())
            self.model.add(PReLU())
            self.model.add(Dropout(self.hidden_dropout))
            # output layer
        self.model.add(Dense(1))


    def fit(self, X_train, y_train, X_valid, y_valid, batch_size):
        # StandardScaler
        x_train = self.scaler.fit_transform(X_train)
        x_valid = self.scaler.fit_transform(X_valid)
        # optimizer
        optimizer = Adam(lr=0.1, beta_1=0.9, beta_2=0.999, decay=0.)
        # Compile
        history = self.model.compile(
            loss='mean_squared_error',
            optimizer=optimizer,
            metrics=['mae']
        )
        # Batch learning and Early stopping
        early_stopping = EarlyStopping(
            patience=5, 
            restore_best_weights=True
            )
        self.history = self.model.fit(
            x_train, y_train,
            epochs=10,
            batch_size=self.batch_size, verbose=0,
            validation_data=(x_valid, y_valid),
            callbacks=[early_stopping]
        )
        return self.history

    def predict(self, X):
        # StandardScaler
        x = self.scaler.fit_transform(X)
        y_pred = self.model.predict(x).flatten()
        return y_pred

#######################################################



# Objective function
def obj(trial):
    # parameter space
    input_dropout = trial.suggest_uniform('input_dropout', 0, 0.3)
    hidden_dropout = trial.suggest_uniform('hidden_dropout', 0, 0.3)
    n_layers = trial.suggest_int('n_layers', 2, 4)
    units = int(trial.suggest_discrete_uniform('units', 32, 256, 32))
    batch_norm = trial.suggest_categorical('batch_norm', ['act', 'non'])
    batch_size = int(trial.suggest_discrete_uniform('batch_size', 32, 128, 32))
    # model building
    model = MLP()
    model.create_graph(
        input_dropout=input_dropout,
        hidden_dropout=hidden_dropout,
        n_layers=n_layers,
        batch_norm=batch_norm,
        units=units
    )
    # CV
    n_splits = params['Regressor']['cv_folds']
    random_state = params['Regressor']['cv_random_state']
    kf = StratifiedKFold(n_splits=n_splits, random_state=random_state, shuffle=True)

    rmse_list = []
    for tr_idx, va_idx in kf.split(X_train, y_train_bins):
        model.fit(
            X_train[tr_idx], y_train[tr_idx],
            X_train[va_idx], y_train[va_idx],
            batch_size
        )
        # prediction
        y_true = y_train[va_idx]
        y_pred = model.predict(X_train[va_idx]).flatten()
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        rmse_list.append(rmse)
    return np.mean(rmse_list)

# optuna
n_trials = params['Regressor']['optuna_trials']
study = optuna.create_study(
    sampler=optuna.samplers.RandomSampler(seed=1541)
)
study.optimize(obj, n_trials=n_trials, n_jobs=-1)

# print('MLP_RMSE: ', study.best_value)
# print('MLP_params: ', study.best_params)

# # save
# with open('../parameter/params_mlp.binaryfile', 'wb') as f:
#     pickle.dump(study.best_params, f)

# %%
params_gragh = p['mlp']['graph']
model = MLP()
model.create_graph(**params_gragh)

# %%
params_gragh = p['mlp']['graph']
model = MLP()
model.create_graph(**params_gragh)
# CV
kf = StratifiedKFold(n_splits=2, random_state=0, shuffle=True)

rmse_list = []
model_list = []
for tr_idx, va_idx in kf.split(X_train, y_train_bins):
    history = model.fit(
        X_train[tr_idx], y_train[tr_idx],
        X_train[va_idx], y_train[va_idx],
        32
    )
    # prediction
    y_true = y_train[va_idx]
    y_pred = model.predict(X_train[va_idx]).flatten()
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    rmse_list.append(rmse)
    model_list.append(history)
    history

# %%
model_list[0].history['val_mean_absolute_error']
# Out:
# [8.551741182804108,
#  19.860546708106995,
#  7.589957237243652,
#  4.785732567310333,
#  7.79670912027359,
#  5.798213839530945,
#  5.7686275243759155,
#  3.326971113681793,
#  5.403219401836395,
#  2.897275850176811]

# %%
# plot learning curve
palette = sns.diverging_palette(220, 20, n=2)
width = np.arange(10)
plt.figure(figsize=(10,8))
plt.title('Learning_Curve', fontsize=15)
plt.xlabel('Epochs', fontsize=15)
plt.ylabel('Loss', fontsize=15)
plt.plot(width, np.array(model_list[0].history['mean_absolute_error']), label='mean_absolute_error', color=palette[0])
plt.plot(width, np.array(model_list[0].history['val_mean_absolute_error']), label='val_mean_absolute_error', color=palette[1])
plt.legend(loc='upper right', fontsize=13)
plt.show()

# %%
model_list[0].history
# Out:
# {'val_loss': [118.05115032196045,
#   679.8573513031006,
#   91.86294770240784,
#   36.93851161003113,
#   84.11181879043579,
#   46.83672857284546,
#   51.2881646156311,
#   21.544888496398926,
#   50.3478569984436,
#   17.37735688686371],
#  'val_mean_absolute_error': [8.551741182804108,
#   19.860546708106995,
#   7.589957237243652,
#   4.785732567310333,
#   7.79670912027359,
#   5.798213839530945,
#   5.7686275243759155,
#   3.326971113681793,
#   5.403219401836395,
#   2.897275850176811],
#  'loss': [408.7613477783203,
#   113.24583038330078,
#   81.9326372680664,
#   47.98620593261719,
#   45.10742617797852,
#   34.131331024169924,
#   40.12320794677734,
#   33.78959359741211,
#   32.63050723266601,
#   33.206442199707034],
#  'mean_absolute_error': [18.34521297454834,
#   8.443874282836914,
#   6.455601211547852,
#   5.112789352416992,
#   4.918063529968261,
#   4.37122066116333,
#   4.763205062866211,
#   4.25409309387207,
#   4.322081127166748,
#   4.124639331817627]}

# %%
pred = model_list[0].predict(X_train)
pred
# Out:
# array([40.160156 , 28.096848 , 41.61521  , 40.11812  , 38.19957  ,
#        31.684519 , 24.951612 , 19.81037  , 14.186078 , 19.726645 ,
#        19.821157 , 23.267317 , 21.837574 , 22.945154 , 21.045616 ,
#        22.592054 , 24.317524 , 18.84968  , 17.665874 , 19.97649  ,
#        15.2847185, 19.308105 , 17.675257 , 16.236544 , 17.925459 ,
#        15.801078 , 17.911552 , 16.61783  , 21.370455 , 23.09231  ,
#        14.792082 , 19.57297  , 12.572731 , 16.186323 , 15.300879 ,
#        24.988337 , 22.652496 , 25.150187 , 24.854395 , 35.959442 ,
#        43.106934 , 36.32122  , 29.69987  , 28.691494 , 25.257883 ,
#        23.242373 , 20.989054 , 19.142563 , 13.388603 , 18.917488 ,
#        21.991648 , 26.089518 , 33.71536  , 27.054085 , 17.275278 ,
#        37.741035 , 29.401276 , 39.208496 , 25.830126 , 23.884726 ,
#        19.687181 , 19.173534 , 27.106794 , 26.062962 , 29.67472  ,
#        34.070606 , 25.498426 , 24.593622 , 19.476545 , 23.97228  ,
# ...

# %%
with open('model.binaryfile', 'wb') as f:
    pickle.dump(model_list[0], f)

# %%
with open('model.binaryfile', 'rb') as f:
    model_ = pickle.load(f)
model_.predict(X_train)
# Out:
# array([40.160156 , 28.096848 , 41.61521  , 40.11812  , 38.19957  ,
#        31.684519 , 24.951612 , 19.81037  , 14.186078 , 19.726645 ,
#        19.821157 , 23.267317 , 21.837574 , 22.945154 , 21.045616 ,
#        22.592054 , 24.317524 , 18.84968  , 17.665874 , 19.97649  ,
#        15.2847185, 19.308105 , 17.675257 , 16.236544 , 17.925459 ,
#        15.801078 , 17.911552 , 16.61783  , 21.370455 , 23.09231  ,
#        14.792082 , 19.57297  , 12.572731 , 16.186323 , 15.300879 ,
#        24.988337 , 22.652496 , 25.150187 , 24.854395 , 35.959442 ,
#        43.106934 , 36.32122  , 29.69987  , 28.691494 , 25.257883 ,
#        23.242373 , 20.989054 , 19.142563 , 13.388603 , 18.917488 ,
#        21.991648 , 26.089518 , 33.71536  , 27.054085 , 17.275278 ,
#        37.741035 , 29.401276 , 39.208496 , 25.830126 , 23.884726 ,
#        19.687181 , 19.173534 , 27.106794 , 26.062962 , 29.67472  ,
#        34.070606 , 25.498426 , 24.593622 , 19.476545 , 23.97228  ,
# ...

# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# len(len(columns) 1013
# C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# [I 2020-02-20 11:01:58,747] Finished trial#0 resulted in value: 0.5724460221429803. Current best value is 0.5724460221429803 with parameters: {'num_leaves': 62, 'subsample': 0.7363706130405656, 'colsample_bytree': 0.8813365546268426, 'min_child_weight': 0.46117814635847987, 'min_child_samples': 58, 'min_split_gain': 0.001044796375287434}.
# C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
# ...

# %% [markdown]
# parameterを現局してやってみる

# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# len(len(columns) 1013
# C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# ...

# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# len(len(columns) 1013
# C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# [I 2020-02-21 11:29:30,130] Finished trial#0 resulted in value: 0.5716255065161974. Current best value is 0.5716255065161974 with parameters: {'num_leaves': 62, 'subsample': 0.7363706130405656, 'colsample_bytree': 0.8813365546268426, 'min_child_weight': 0.46117814635847987, 'min_child_samples': 58, 'min_split_gain': 0.001044796375287434}.
# C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
# ...

# %% [markdown]
# 層化抽出をしないでモデルを構築する

# %%
# %run -i run.py
# Out:
# X_train.shape (1379, 1013)
# y_train.shape (1379,)
# len(len(columns) 1013
# [I 2020-02-22 12:48:26,890] Finished trial#1 resulted in value: 0.5717638329932637. Current best value is 0.5717638329932637 with parameters: {'num_leaves': 57, 'subsample': 0.6550087783104126, 'colsample_bytree': 0.7506557031468073, 'min_child_weight': 0.4242072849836787, 'min_child_samples': 45, 'min_split_gain': 0.0009211712509502564}.
# [I 2020-02-22 12:48:27,690] Finished trial#9 resulted in value: 0.5729254961933327. Current best value is 0.5717638329932637 with parameters: {'num_leaves': 57, 'subsample': 0.6550087783104126, 'colsample_bytree': 0.7506557031468073, 'min_child_weight': 0.4242072849836787, 'min_child_samples': 45, 'min_split_gain': 0.0009211712509502564}.
# ...
