# %%
# %run -i rf_opt.py
# %run -i lgb_opt.py
# %run -i xgb_opt.py
# %run -i ctb_opt.py
# Out:
# c:\users\kotak\miniconda3\envs\ml\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning:
#
# Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#
# c:\users\kotak\miniconda3\envs\ml\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning:
#
# Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#
# ...
