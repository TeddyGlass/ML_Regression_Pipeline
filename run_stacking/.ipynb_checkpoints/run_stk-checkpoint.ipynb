# %%
# %run -i stacking_cv.py
# Out:
# C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# [I 2020-02-21 15:05:31,546] Finished trial#0 resulted in value: 0.5561351479422643. Current best value is 0.5561351479422643 with parameters: {'alpha': 0.015951127639983773, 'solver': 'lsqr', 'max_iter': 98}.
# ...

# %% [markdown]
# ### ビン化層化抽出しないバージョンで

# %%
# %run -i stacking_cv.py
# Out:
# [I 2020-02-22 14:08:44,686] Finished trial#3 resulted in value: 0.5497163665088833. Current best value is 0.5497163665088833 with parameters: {'alpha': 0.39460784071733357, 'solver': 'svd', 'max_iter': 216}.
# [I 2020-02-22 14:08:44,782] Finished trial#0 resulted in value: 0.5497315779898214. Current best value is 0.5497163665088833 with parameters: {'alpha': 0.39460784071733357, 'solver': 'svd', 'max_iter': 216}.
# [I 2020-02-22 14:08:44,861] Finished trial#6 resulted in value: 0.5500268144830537. Current best value is 0.5497163665088833 with parameters: {'alpha': 0.39460784071733357, 'solver': 'svd', 'max_iter': 216}.
# [I 2020-02-22 14:08:44,940] Finished trial#8 resulted in value: 0.5497309355075132. Current best value is 0.5497163665088833 with parameters: {'alpha': 0.39460784071733357, 'solver': 'svd', 'max_iter': 216}.
# ...
