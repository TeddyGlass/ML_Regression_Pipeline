# %%
# %run -i stacking_cv.py
# Out:
# C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# [I 2020-02-20 16:47:00,952] Finished trial#6 resulted in value: 0.5571509281028555. Current best value is 0.5571509281028555 with parameters: {'alpha': 0.3297464803293165, 'solver': 'cholesky', 'max_iter': 450}.
# [I 2020-02-20 16:47:01,060]C:\Users\mmi-05\Miniconda3\envs\ML\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# ...
