# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
import optuna
# Out:
# /Users/kurosaki/opt/miniconda3/envs/ML/lib/python3.7/site-packages/lightgbm/__init__.py:48: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
from sklearn.datasets import load_boston
from conf import Paramset
from trainer import Trainer

# %%
from trainer import Trainer
from conf import Paramset
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
import numpy as np


class Optimizer:

    def __init__(self, model, X, y):
        self.model = model
        self.model_type = type(self.model).__name__
        self.X = X
        self.y = y
        paramset = Paramset(self.model)
        paramset.swiching_lr('params_search')
        self.PARAMS = paramset.generate_params()
        self.SPACE = {}

    def swich_space(self, trial):
        if self.model_type == 'LGBMRegressor':
            self.SPACE = {
                'num_leaves': trial.suggest_int(
                    'num_leaves', 32, 2*32),
                'subsample': trial.suggest_uniform('subsample', 0.60, 0.80),
                'colsample_bytree': trial.suggest_uniform(
                    'colsample_bytree', 0.60, 0.80),
                'bagging_freq': int(trial.suggest_discrete_uniform(
                    'bagging_freq', 1, 51, 5)),
                'min_child_weight': trial.suggest_loguniform(
                    'min_child_weight', 1, 32),
                'min_child_samples': int(trial.suggest_discrete_uniform(
                    'min_child_samples', 128, 512, 16)),
                'min_split_gain': trial.suggest_loguniform(
                    'min_split_gain', 1e-5, 1e-1)
            }
        elif self.model_type == 'XGBRegressor':
            self.SPACE = {
                'subsample': trial.suggest_uniform(
                    'subsample', 0.65, 0.85),
                'colsample_bytree': trial.suggest_uniform(
                    'colsample_bytree', 0.65, 0.80),
                'gamma': trial.suggest_loguniform(
                    'gamma', 1e-8, 1.0),
                'min_child_weight': trial.suggest_loguniform(
                    'min_child_weight', 1, 32)
            }

    def generate_func(self):
        n_splits = 5
        random_state = 1214
        early_stopping_rounds = 200
        kf = KFold(n_splits=n_splits, random_state=random_state, shuffle=True)
        self.PARAMS.update(self.SPACE)
        rmse_list = []
        for tr_idx, va_idx in kf.split(self.X, self.y):
            model = Trainer(self.model(**self.PARAMS))
            model.fit(
                self.X[tr_idx],
                self.y[tr_idx],
                self.X[va_idx],
                self.y[va_idx],
                early_stopping_rounds
                )
            # scoring
            y_pred = model.predict(
                self.X[va_idx],
                ntree_limit=model.get_best_iteration()
            )
            y_true = self.y[va_idx]
            rmse = np.sqrt(mean_squared_error(y_true, y_pred))
            rmse_list.append(rmse)
        return np.mean(rmse_list)

# %% [markdown]
# 13:21

# %%
class Objective:
    
    '''
    # Usage
    obj = Objective(LGBMRegressor(), X, y)
    study = optuna.create_study(sampler=optuna.samplers.RandomSampler(seed=123))
    study.optimize(obj, n_trials=10, n_jobs=-1)
    '''   
    
    def __init__(self, model, x, y):
        self.model = model
        self.model_type = type(self.model).__name__
        self.x = x
        self.y = y
        self.n_splits = 5
        self.random_state = 1214
        self.early_stopping_rounds = 200
        paramset = Paramset(self.model)
        paramset.swiching_lr('params_search')
        self.PARAMS = paramset.generate_params()
    
    def __call__(self, trial):
        
        if self.model_type == 'LGBMRegressor':
            SPACE = {
                'num_leaves': trial.suggest_int(
                'num_leaves', 32, 2*32),
                'subsample': trial.suggest_uniform('subsample', 0.60, 0.80),
                'colsample_bytree': trial.suggest_uniform(
                    'colsample_bytree', 0.60, 0.80),
                'bagging_freq': int(trial.suggest_discrete_uniform(
                    'bagging_freq', 1, 51, 5)),
                'min_child_weight': trial.suggest_loguniform(
                    'min_child_weight', 1, 32),
                'min_child_samples': int(trial.suggest_discrete_uniform(
                    'min_child_samples', 128, 512, 16)),
                'min_split_gain': trial.suggest_loguniform(
                    'min_split_gain', 1e-5, 1e-1)
            }
            self.PARAMS.update(SPACE)
            # cross validation
            kf = KFold(n_splits=self.n_splits, random_state=self.random_state, shuffle=True)
            RMSE = []
            for tr_idx, va_idx in kf.split(self.x, self.y):
                reg = Trainer(LGBMRegressor(**self.PARAMS))
                reg.fit(
                    self.x[tr_idx],
                    self.y[tr_idx],
                    self.x[va_idx],
                    self.y[va_idx],
                    self.early_stopping_rounds
                )
                y_pred = reg.predict(self.x[va_idx]) # best_iteration
                rmse = np.sqrt(mean_squared_error(self.y[va_idx], y_pred))
                RMSE.append(rmse)
            return np.mean(RMSE)
        
        elif model_type == 'XGBRegressor':
            SPACE = {
                'subsample': trial.suggest_uniform(
                    'subsample', 0.65, 0.85),
                'colsample_bytree': trial.suggest_uniform(
                    'colsample_bytree', 0.65, 0.80),
                'gamma': trial.suggest_loguniform(
                    'gamma', 1e-8, 1.0),
                'min_child_weight': trial.suggest_loguniform(
                    'min_child_weight', 1, 32)
            }
            self.PARAMS.update(SPACE)
            # cross validation
            kf = KFold(n_splits=self.n_splits, random_state=self.random_state, shuffle=True)
            RMSE = []
            for tr_idx, va_idx in kf.split(self.x, self.y):
                reg = Trainer(XGBRegressor(**self.PARAMS))
                reg.fit(
                    self.x[tr_idx],
                    self.y[tr_idx],
                    self.x[va_idx],
                    self.y[va_idx],
                    self.early_stopping_rounds
                )
                y_pred = reg.predict(self.x[va_idx]) # best_iteration
                rmse = np.sqrt(mean_squared_error(self.y[va_idx], y_pred))
                RMSE.append(rmse)
            return np.mean(RMSE)

# %%
# data
bos = load_boston()
X = bos['data']
y = bos['target']
# opt
obj = Objective(LGBMRegressor(), X, y)
study = optuna.create_study(
    sampler=optuna.samplers.RandomSampler(seed=123)
)
study.optimize(obj, n_trials=10, n_jobs=-1)
# Out:
# [I 2020-05-08 14:49:39,505] Finished trial#4 with value: 9.167906164431585 with parameters: {'num_leaves': 37, 'subsample': 0.6867402345359057, 'colsample_bytree': 0.6861725526659288, 'bagging_freq': 26.0, 'min_child_weight': 4.374601043427872, 'min_child_samples': 240.0, 'min_split_gain': 0.0005074639876783335}. Best is trial#4 with value: 9.167906164431585.
# [I 2020-05-08 14:49:39,573] Finished trial#3 with value: 9.167906164431585 with parameters: {'num_leaves': 60, 'subsample': 0.7444886765140444, 'colsample_bytree': 0.6645917827706357, 'bagging_freq': 16.0, 'min_child_weight': 2.2058216603043252, 'min_child_samples': 240.0, 'min_split_gain': 0.0033412155613488934}. Best is trial#4 with value: 9.167906164431585.
# [I 2020-05-08 14:49:39,625] Finished trial#2 with value: 9.167906164431585 with parameters: {'num_leaves': 35, 'subsample': 0.6350903512294985, 'colsample_bytree': 0.7063102747683677, 'bagging_freq': 26.0, 'min_child_weight': 9.012983769833248, 'min_child_samples': 464.0, 'min_split_gain': 0.007903533518289981}. Best is trial#4 with value: 9.167906164431585.
# [I 2020-05-08 14:49:39,678] Finished trial#1 with value: 9.167906164431585 with parameters: {'num_leaves': 41, 'subsample': 0.6802035113322407, 'colsample_bytree': 0.7254634018675233, 'bagging_freq': 16.0, 'min_child_weight': 2.3356051295794096, 'min_child_samples': 400.0, 'min_split_gain': 0.0023747046283529526}. Best is trial#4 with value: 9.167906164431585.
# [I 2020-05-08 14:49:39,734] Finished trial#0 with value: 9.167906164431585 with parameters: {'num_leaves': 34, 'subsample': 0.6453702907128406, 'colsample_bytree': 0.7102629538165782, 'bagging_freq': 36.0, 'min_child_weight': 4.333498786479689, 'min_child_samples': 512.0, 'min_split_gain': 0.005486797781181633}. Best is trial#4 with value: 9.167906164431585.
# [I 2020-05-08 14:49:39,842] Finished trial#7 with value: 9.167906164431585 with parameters: {'num_leaves': 49, 'subsample': 0.7206120256821855, 'colsample_bytree': 0.709013601293293, 'bagging_freq': 16.0, 'min_child_weight': 2.8691113202778844, 'min_child_samples': 288.0, 'min_split_gain': 0.005311327280336983}. Best is trial#4 with value: 9.167906164431585.
# [I 2020-05-08 14:49:39,844] Finished trial#5 with value: 9.167906164431585 with parameters: {'num_leaves': 62, 'subsample': 0.702352675053234, 'colsample_bytree': 0.6928536111473336, 'bagging_freq': 31.0, 'min_child_weight': 2.8535290885692626, 'min_child_samples': 320.0, 'min_split_gain': 0.005408186424793596}. Best is trial#4 with value: 9.167906164431585.
# [I 2020-05-08 14:49:39,899] Finished trial#6 with value: 9.167906164431585 with parameters: {'num_leaves': 39, 'subsample': 0.6217857904479418, 'colsample_bytree': 0.6990983575367329, 'bagging_freq': 11.0, 'min_child_weight': 4.545072520323323, 'min_child_samples': 416.0, 'min_split_gain': 0.0008386263650487486}. Best is trial#4 with value: 9.167906164431585.
# [I 2020-05-08 14:49:40,539] Finished trial#8 with value: 9.167906164431585 with parameters: {'num_leaves': 43, 'subsample': 0.653560764358077, 'colsample_bytree': 0.6913495833714511, 'bagging_freq': 11.0, 'min_child_weight': 18.1924001188465, 'min_child_samples': 224.0, 'min_split_gain': 0.0013190098683738638}. Best is trial#4 with value: 9.167906164431585.
# [I 2020-05-08 14:49:40,590] Finished trial#9 with value: 9.167906164431585 with parameters: {'num_leaves': 41, 'subsample': 0.6166389976664878, 'colsample_bytree': 0.7527365682886676, 'bagging_freq': 11.0, 'min_child_weight': 1.960354820304434, 'min_child_samples': 352.0, 'min_split_gain': 2.414627077337042e-05}. Best is trial#4 with value: 9.167906164431585.

# %%
def swich_space(model_type):
    if model_type == 'LGBMRegressor':
        global trial
        SPACE = {
            'num_leaves': trial.suggest_int(
                'num_leaves', 32, 2*32),
            'subsample': trial.suggest_uniform('subsample', 0.60, 0.80),
            'colsample_bytree': trial.suggest_uniform(
                'colsample_bytree', 0.60, 0.80),
            'bagging_freq': int(trial.suggest_discrete_uniform(
                'bagging_freq', 1, 51, 5)),
            'min_child_weight': trial.suggest_loguniform(
                'min_child_weight', 1, 32),
            'min_child_samples': int(trial.suggest_discrete_uniform(
                'min_child_samples', 128, 512, 16)),
            'min_split_gain': trial.suggest_loguniform(
                'min_split_gain', 1e-5, 1e-1)
        }
        return SPACE
    elif model_type == 'XGBRegressor':
        global trial
        SPACE = {
            'subsample': trial.suggest_uniform(
                'subsample', 0.65, 0.85),
            'colsample_bytree': trial.suggest_uniform(
                'colsample_bytree', 0.65, 0.80),
            'gamma': trial.suggest_loguniform(
                'gamma', 1e-8, 1.0),
            'min_child_weight': trial.suggest_loguniform(
                'min_child_weight', 1, 32)
        }
        return SPACE
# Out:
#   File "<ipython-input-22-4b79ef15ea9e>", line 24
#     'subsample', 0.65, 0.85),
#     ^
# SyntaxError: name 'trial' is used prior to global declaration

# %%
def generate_func(trial):
    n_splits = 5
    random_state = 1214
    early_stopping_rounds = 200
    kf = KFold(n_splits=n_splits, random_state=random_state, shuffle=True)
    SPACE = swich_space(type(XGBRegressor).__name__)
    PARAMS.update(SPACE)
    rmse_list = []
    for tr_idx, va_idx in kf.split(X, y):
        model = Trainer(XGBRegressor(**PARAMS))
        model.fit(
            X[tr_idx],
            y[tr_idx],
            X[va_idx],
            y[va_idx],
            early_stopping_rounds
            )
        # scoring
        y_pred = model.predict(
            X[va_idx],
            ntree_limit=model.get_best_iteration()
        )
        y_true = y[va_idx]
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        rmse_list.append(rmse)
    return np.mean(rmse_list)

# %%
# data
bos = load_boston()
X = bos['data']
y = bos['target']

# params
paramset = Paramset(XGBRegressor())
paramset.swiching_lr('params_search')
PARAMS = paramset.generate_params()

# 
study = optuna.create_study(
    sampler=optuna.samplers.RandomSampler(seed=123)
)
study.optimize(generate_func, n_trials=10, n_jobs=-1)
# Out:
# [W 2020-05-08 13:16:37,570] Setting status of trial#0 as TrialState.FAIL because of the following error: TypeError("'NoneType' object is not iterable")
# Traceback (most recent call last):
#   File "/Users/kurosaki/opt/miniconda3/envs/ML/lib/python3.7/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "<ipython-input-20-d64205e96f08>", line 7, in generate_func
#     PARAMS.update(SPACE)
# TypeError: 'NoneType' object is not iterable
# [W 2020-05-08 13:16:37,571] Setting status of trial#1 as TrialState.FAIL because of the following error: TypeError("'NoneType' object is not iterable")
# Traceback (most recent call last):
#   File "/Users/kurosaki/opt/miniconda3/envs/ML/lib/python3.7/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "<ipython-input-20-d64205e96f08>", line 7, in generate_func
#     PARAMS.update(SPACE)
# TypeError: 'NoneType' object is not iterable
# [W 2020-05-08 13:16:37,572] Setting status of trial#2 as TrialState.FAIL because of the following error: TypeError("'NoneType' object is not iterable")
# Traceback (most recent call last):
#   File "/Users/kurosaki/opt/miniconda3/envs/ML/lib/python3.7/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "<ipython-input-20-d64205e96f08>", line 7, in generate_func
#     PARAMS.update(SPACE)
# TypeError: 'NoneType' object is not iterable
# [W 2020-05-08 13:16:37,572] Setting status of trial#3 as TrialState.FAIL because of the following error: TypeError("'NoneType' object is not iterable")
# Traceback (most recent call last):
#   File "/Users/kurosaki/opt/miniconda3/envs/ML/lib/python3.7/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "<ipython-input-20-d64205e96f08>", line 7, in generate_func
#     PARAMS.update(SPACE)
# TypeError: 'NoneType' object is not iterable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-c3faefd12272> in <module>
#      13     sampler=optuna.samplers.RandomSampler(seed=123)
#      14 )
# ---> 15 study.optimize(generate_func, n_trials=10, n_jobs=-1)
#
# ~/opt/miniconda3/envs/ML/lib/python3.7/site-packages/optuna/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     370                             func, 1, timeout, catch, callbacks, gc_after_trial, time_start
#     371                         )
# --> 372                         for _ in _iter
#     373                     )
#     374         finally:
#
# ~/opt/miniconda3/envs/ML/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1015
#    1016             with self._backend.retrieval_context():
# -> 1017                 self.retrieve()
#    1018             # Make sure that we get a last message telling us we are done
#    1019             elapsed_time = time.time() - self._start_time
#
# ~/opt/miniconda3/envs/ML/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     907             try:
#     908                 if getattr(self._backend, 'supports_timeout', False):
# --> 909                     self._output.extend(job.get(timeout=self.timeout))
#     910                 else:
#     911                     self._output.extend(job.get())
#
# ~/opt/miniconda3/envs/ML/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# ~/opt/miniconda3/envs/ML/lib/python3.7/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     119         job, i, func, args, kwds = task
#     120         try:
# --> 121             result = (True, func(*args, **kwds))
#     122         except Exception as e:
#     123             if wrap_exception and func is not _helper_reraises_exception:
#
# ~/opt/miniconda3/envs/ML/lib/python3.7/site-packages/joblib/_parallel_backends.py in __call__(self, *args, **kwargs)
#     606     def __call__(self, *args, **kwargs):
#     607         try:
# --> 608             return self.func(*args, **kwargs)
#     609         except KeyboardInterrupt:
#     610             # We capture the KeyboardInterrupt and reraise it as
#
# ~/opt/miniconda3/envs/ML/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~/opt/miniconda3/envs/ML/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~/opt/miniconda3/envs/ML/lib/python3.7/site-packages/optuna/study.py in _optimize_sequential(self, func, n_trials, timeout, catch, callbacks, gc_after_trial, time_start)
#     624                     break
#     625
# --> 626             self._run_trial_and_callbacks(func, catch, callbacks, gc_after_trial)
#     627
#     628             self._progress_bar.update((datetime.datetime.now() - time_start).total_seconds())
#
# ~/opt/miniconda3/envs/ML/lib/python3.7/site-packages/optuna/study.py in _run_trial_and_callbacks(self, func, catch, callbacks, gc_after_trial)
#     654         # type: (...) -> None
#     655
# --> 656         trial = self._run_trial(func, catch, gc_after_trial)
#     657         if callbacks is not None:
#     658             frozen_trial = self._storage.get_trial(trial._trial_id)
#
# ~/opt/miniconda3/envs/ML/lib/python3.7/site-packages/optuna/study.py in _run_trial(self, func, catch, gc_after_trial)
#     675
#     676         try:
# --> 677             result = func(trial)
#     678         except exceptions.TrialPruned as e:
#     679             message = "Setting status of trial#{} as {}. {}".format(
#
# <ipython-input-20-d64205e96f08> in generate_func(trial)
#       5     kf = KFold(n_splits=n_splits, random_state=random_state, shuffle=True)
#       6     SPACE = swich_space(type(XGBRegressor).__name__)
# ----> 7     PARAMS.update(SPACE)
#       8     rmse_list = []
#       9     for tr_idx, va_idx in kf.split(X, y):
#
# TypeError: 'NoneType' object is not iterable
# [W 2020-05-08 13:16:37,573] Setting status of trial#4 as TrialState.FAIL because of the following error: TypeError("'NoneType' object is not iterable")
# Traceback (most recent call last):
#   File "/Users/kurosaki/opt/miniconda3/envs/ML/lib/python3.7/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "<ipython-input-20-d64205e96f08>", line 7, in generate_func
#     PARAMS.update(SPACE)
# TypeError: 'NoneType' object is not iterable
# [W 2020-05-08 13:16:37,573] Setting status of trial#5 as TrialState.FAIL because of the following error: TypeError("'NoneType' object is not iterable")
# Traceback (most recent call last):
#   File "/Users/kurosaki/opt/miniconda3/envs/ML/lib/python3.7/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "<ipython-input-20-d64205e96f08>", line 7, in generate_func
#     PARAMS.update(SPACE)
# TypeError: 'NoneType' object is not iterable
# [W 2020-05-08 13:16:37,574] Setting status of trial#6 as TrialState.FAIL because of the following error: TypeError("'NoneType' object is not iterable")
# Traceback (most recent call last):
#   File "/Users/kurosaki/opt/miniconda3/envs/ML/lib/python3.7/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "<ipython-input-20-d64205e96f08>", line 7, in generate_func
#     PARAMS.update(SPACE)
# TypeError: 'NoneType' object is not iterable
# [W 2020-05-08 13:16:37,575] Setting status of trial#7 as TrialState.FAIL because of the following error: TypeError("'NoneType' object is not iterable")
# Traceback (most recent call last):
#   File "/Users/kurosaki/opt/miniconda3/envs/ML/lib/python3.7/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "<ipython-input-20-d64205e96f08>", line 7, in generate_func
#     PARAMS.update(SPACE)
# TypeError: 'NoneType' object is not iterable
# [W 2020-05-08 13:16:37,664] Setting status of trial#8 as TrialState.FAIL because of the following error: TypeError("'NoneType' object is not iterable")
# Traceback (most recent call last):
#   File "/Users/kurosaki/opt/miniconda3/envs/ML/lib/python3.7/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "<ipython-input-20-d64205e96f08>", line 7, in generate_func
#     PARAMS.update(SPACE)
# TypeError: 'NoneType' object is not iterable

# %%
# params
paramset = Paramset(XGBRegressor())
paramset.swiching_lr('params_search')
XGB_PARAMS = paramset.generate_params()
XGB_PARAMS
# Out:
# {'learing_rate': 0.05,
